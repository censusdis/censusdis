# %% [markdown]
# # ACS Data Profile Demo

# %% [markdown]
# ## Introduction
#
# This notebook demonstrates how to load and plot
# [US Census American Community Survey (ACS) 5-year Data Profiles](https://api.census.gov/data/2021/acs/acs5/profile.html).

# %% [markdown]
# ## Imports and configuration

# %%
import censusdis.data as ced
import censusdis.maps as cem

from matplotlib.ticker import FuncFormatter

# %%
# Set your API key here.
CENSUS_API_KEY = None

# %%
YEAR = 2021
DATASET = "acs/acs5/profile"

# %%
TOTAL_HOUSEHOLDS_VARIABLE = "DP02_0001E"

# %% [markdown]
# ## Download the data

# %%
gdf = ced.download(
    DATASET, YEAR, ["NAME", TOTAL_HOUSEHOLDS_VARIABLE], state="*", with_geometry=True
)

# %% [markdown]
# ## Plot the data

# %%
ax = cem.plot_us(
    gdf,
    TOTAL_HOUSEHOLDS_VARIABLE,
    figsize=(12, 6),
    legend=True,
    cmap="Blues",
    edgecolor="black",
    linewidth=0.25,
    vmin=0,
    vmax=15_000_000,
    legend_kwds={"format": FuncFormatter(lambda x, pos: f"{x:,.0f}")},
)

ax.axis("off")
ax.set_title("Total Households")

None

# %%
gdf
# Out:
#    STATE                  NAME  DP02_0001E  \
# 0     01               Alabama   1902983.0
# 1     02                Alaska    260561.0
# 2     04               Arizona   2683557.0
# 3     05              Arkansas   1158460.0
# 4     06            California  13217586.0
# 5     08              Colorado   2227932.0
# 6     09           Connecticut   1397324.0
# 7     10              Delaware    381097.0
# 8     11  District of Columbia    310104.0
# 9     12               Florida   8157420.0
# 10    13               Georgia   3885371.0
# 11    15                Hawaii    478413.0
# 12    16                 Idaho    657101.0
# 13    17              Illinois   4930255.0
# 14    18               Indiana   2622601.0
# 15    19                  Iowa   1275893.0
# 16    20                Kansas   1139738.0
# 17    21              Kentucky   1748475.0
# 18    22             Louisiana   1748688.0
# 19    23                 Maine    571064.0
# 20    24              Maryland   2294270.0
# ...
