# %% [markdown]
# # Explore Interactively
#
# `censusdis` uses [`geopandas`](https://geopandas.org/en/stable) under the hood to
# represent data and geometry when `censusdis.data.download` is called with the
# `with_geometry=True` option.
#
# `geopandas.GeoDataFrame`s support interactive views on top of maps using the powerful
# `.explore()` method. In order to enable it, there are a few optional packages that
# need to be installed. In order to do so, you simply
#
# ```shell
# pip install censusdis[explore]
# ```
#
# instead of the standard
#
# ```shell
# pip install censusdis
# ```
#
# Assuming you have done that, you can run this notebook and get an interactive view of the
# median income of counties in Arkansas from 2022 ACS-5 data.
#
# Note that `geopandas.GeoDataFrame.explore()` has
# [tons of options](https://geopandas.org/en/stable/docs/reference/api/geopandas.GeoDataFrame.explore.html).
# We have only just scratched the surface here, but you can use them to generate a wide variety of interactive
# maps from the data you download with `censusdis`.

# %%
import censusdis.data as ced
from censusdis.datasets import ACS5
from censusdis.states import AR

# %%
MEDIAN_INCOME = "B19013_001E"

# %%
gdf_counties = ced.download(
    dataset=ACS5,
    vintage=2022,
    download_variables=["NAME", MEDIAN_INCOME],
    state=AR,
    county="*",
    with_geometry=True,
)

# %%
# The output of this cell should be an interactive map.
gdf_counties.explore(
    column=MEDIAN_INCOME,
    cmap="Blues",
    vmin=25_000,
    vmax=100_000,
    legend_kwds={"caption": "Median Income"},
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_510b483d8f1a06a42a62d6c0a77d508f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_510b483d8f1a06a42a62d6c0a77d508f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_510b483d8f1a06a42a62d6c0a77d508f = L.map(
#                 &quot;map_510b483d8f1a06a42a62d6c0a77d508f&quot;,
#                 {
#                     center: [34.751945500000005, -92.12946099999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_510b483d8f1a06a42a62d6c0a77d508f);
#
#
#
#
#
#             var tile_layer_e4db638b85473788424aa86abd21f441 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e4db638b85473788424aa86abd21f441.addTo(map_510b483d8f1a06a42a62d6c0a77d508f);
#
#
#             map_510b483d8f1a06a42a62d6c0a77d508f.fitBounds(
#                 [[33.004291, -94.617919], [36.4996, -89.641003]],
#                 {}
#             );
#
#
#         function geo_json_d5ba65257b21d0d1e84b9fa700a3330a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#7fb9da&quot;, &quot;fillColor&quot;: &quot;#7fb9da&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;10&quot;: case &quot;30&quot;:
#                     return {&quot;color&quot;: &quot;#c2d9ee&quot;, &quot;fillColor&quot;: &quot;#c2d9ee&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;13&quot;: case &quot;51&quot;:
#                     return {&quot;color&quot;: &quot;#b7d4ea&quot;, &quot;fillColor&quot;: &quot;#b7d4ea&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#1663aa&quot;, &quot;fillColor&quot;: &quot;#1663aa&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;31&quot;:
#                     return {&quot;color&quot;: &quot;#a1cbe2&quot;, &quot;fillColor&quot;: &quot;#a1cbe2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;37&quot;:
#                     return {&quot;color&quot;: &quot;#c7dbef&quot;, &quot;fillColor&quot;: &quot;#c7dbef&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#77b5d9&quot;, &quot;fillColor&quot;: &quot;#77b5d9&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;#8abfdd&quot;, &quot;fillColor&quot;: &quot;#8abfdd&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#d9e7f5&quot;, &quot;fillColor&quot;: &quot;#d9e7f5&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#a0cbe2&quot;, &quot;fillColor&quot;: &quot;#a0cbe2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#b0d2e7&quot;, &quot;fillColor&quot;: &quot;#b0d2e7&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;: case &quot;29&quot;:
#                     return {&quot;color&quot;: &quot;#aacfe5&quot;, &quot;fillColor&quot;: &quot;#aacfe5&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;#94c4df&quot;, &quot;fillColor&quot;: &quot;#94c4df&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;17&quot;: case &quot;57&quot;:
#                     return {&quot;color&quot;: &quot;#a4cce3&quot;, &quot;fillColor&quot;: &quot;#a4cce3&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;19&quot;:
#                     return {&quot;color&quot;: &quo
