# %% [markdown]
# # Querying Available Data Sets
#
# The US Census publishes dozens of data sets per year. They have published over
# 1,300 data sets in all via their API. Some, like
# the *American Community Survey: 5-Year Estimates: Data Tables*
# are widely known and used, but there are plenty of other interesting and useful
# data sets you might want to load.
#
# `censusdis` supports querying avaialble data sets for a given year or for all time.
#
# We have not loaded all variables for all data sets for all years, but
# `censusdis` should be able to.
# If you encounter one it cannot load, please file and issue at
# https://github.com/vengroff/censusdis/issues and we will look into it.

# %% [markdown]
# ## Imports and configuration

# %%
import censusdis.data as ced
import pandas as pd

# %% [markdown]
# ## Data sets available for a given year

# %%
YEAR = 2020

# %%
df_datasets_for_year = ced.variables.all_data_sets(year=YEAR)

df_datasets_for_year
# Out:
#     YEAR            DATASET  \
# 0   2020              abscb
# 1   2020             abscbo
# 2   2020              abscs
# 3   2020             absmcb
# 4   2020           acs/acs5
# 5   2020  acs/acs5/cprofile
# 6   2020   acs/acs5/profile
# 7   2020      acs/acs5/pums
# 8   2020    acs/acs5/pumspr
# 9   2020   acs/acs5/subject
# 10  2020          acs/flows
# 11  2020                cbp
# 12  2020       cps/arts/feb
# 13  2020       cps/asec/mar
# 14  2020      cps/basic/apr
# 15  2020      cps/basic/aug
# 16  2020      cps/basic/dec
# 17  2020      cps/basic/feb
# 18  2020      cps/basic/jan
# 19  2020      cps/basic/jul
# 20  2020      cps/basic/jun
# 21  2020      cps/basic/mar
# 22  2020      cps/basic/may
# 23  2020      cps/basic/nov
# 24  2020      cps/basic/oct
# 25  2020      cps/basic/sep
# 26  2020       cps/dwjt/jan
# 27  2020  cps/fertility/jun
# 28  2020    cps/foodsec/dec
# 29  2020     cps/school/oct
# 30  2020       cps/vets/aug
# 31  2020     cps/voting/nov
# 32  2020          dec/cd118
# 33  2020          dec/ddhca
# 34  2020            dec/dhc
# 35  2020          dec/dhcas
# 36  2020          dec/dhcgu
# 37  2020          dec/dhcmp
# 38  2020          dec/dhcvi
# 39  2020             dec/dp
# 40  2020           dec/dpas
# 41  2020           dec/dpgu
# 42  2020           dec/dpmp
# 43  2020           dec/dpvi
# 44  2020            dec/pes
# 45  2020             dec/pl
# 46  2020   dec/responserate
# 47  2020             nonemp
# 48  2020     pdb/blockgroup
# 49  2020    pdb/statecounty
# 50  2020          pdb/tract
#
#                                                 TITLE  \
# 0   Economic Surveys: Annual Business Survey: Char...
# 1   Economic Surveys: Annual Business Survey: Char...
# 2   Economic Surveys: Annual Business Survey: Comp...
# 3   Economic Surveys: Annual Business Survey: Modu...
# 4   American Community Survey: 5-Year Estimates: D...
# 5   American Community Survey: 5-Year Estimates: C...
# 6   American Community Survey: 5-Year Estimates: D...
# 7   2020 American Community Survey: 5-Year Estimat...
# 8   2020 American Community Survey: 5-Year Estimat...
# 9   American Community Survey: 5-Year Estimates: S...
# 10  2016-2020 American Community Survey: Migration...
# 11  Economic Surveys: Business Patterns: County Bu...
# 12  Current Population Survey: Arts Benchmarking S...
# 13  Current Population Survey Annual Social and Ec...
# 14           Current Population Survey: Basic Monthly
# 15           Current Population Survey: Basic Monthly
# 16           Current Population Survey: Basic Monthly
# 17           Current Population Survey: Basic Monthly
# 18           Current Population Survey: Basic Monthly
# 19           Current Population Survey: Basic Monthly
# 20           Current Population Survey: Basic Monthly
# 21           Current Population Survey: Basic Monthly
# 22           Current Population Survey: Basic Monthly
# 23           Current Population Survey: Basic Monthly
# 24           Current Population Survey: Basic Monthly
# 25           Current Population Survey: Basic Monthly
# 26  Current Population Survey: Displaced Worker, E...
# 27    Current Population Survey: Fertility Supplement
# 28  Current Population Survey: Food Security Suppl...
# 29  Current Population Survey: School Enrollment S...
# 30     Current Population Survey: Veterans Supplement
# 31       Current Population Survey: Voting Supplement
# 32  Decennial Census: 118th Congressional District...
# 33  Decennial Census: Detailed Demographic and Hou...
# 34  Decennial Census: Demographic and Housing Char...
# 35  Decennial Census of Island Areas: American Sam...
# 36  Decennial Census of Island Areas: Guam Demogra...
# 37  Decennial Census of Island Areas: Commonwealth...
# 38  Decennial Census of Island Areas: U.S. Virgin ...
# 39              Decennial Census: Demographic Profile
# 40  Decennial Census of Island Areas: American Sam...
# 41  Decennial Census of Island Areas: Guam Demogra...
# 42  2020 Commonwealth of the Northern Mariana Isla...
# 43  Decennial Census of Island Areas: U.S. Virgin ...
# 44  Decennial Census: Decennial Post-Enumeration S...
# 45   Decennial Census: Redistricting Data (PL 94-171)
# 46     Decennial Census: Decennial Self-Response Rate
# 47           Economic Surveys: Nonemployer Statistics
# 48                Planning Database Block Group Level
# 49    2020 Planning Database - State and County Level
# 50                     Planning Database: Tract Level
#
#                                           DESCRIPTION  \
# 0   The Annual Business Survey (ABS) provides info...
# 1   The Annual Business Survey (ABS) provides info...
# 2   The Annual Business Survey (ABS) provides info...
# 3   The Annual Business Survey (ABS) provides info...
# 4   The American Community Survey (ACS) is an ongo...
# 5   The American Community Survey (ACS) is an ongo...
# 6   The American Community Survey (ACS) is an ongo...
# 7   The American Community Survey (ACS) Public Use...
# 8   The Public Use Microdata Sample (PUMS) for Pue...
# 9   The American Community Survey (ACS) is an ongo...
# 10  Migration flows are derived from the relations...
# 11  County Business Patterns (CBP) is an annual se...
# 12  ABS collects information about individual atte...
# 13  The Annual Social and Economic Supplement or M...
# 14  To provide estimates of employment, unemployme...
# 15  To provide estimates of employment, unemployme...
# 16  To provide estimates of employment, unemployme...
# 17  To provide estimates of employment, unemployme...
# 18  To provide estimates of employment, unemployme...
# 19  To provide estimates of employment, unemployme...
# 20  To provide estimates of employment, unemployme...
# 21  To provide estimates of employment, unemployme...
# 22  To provide estimates of employment, unemployme...
# 23  To provide estimates of employment, unemployme...
# 24  To provide estimates of employment, unemployme...
# 25  To provide estimates of employment, unemployme...
# 26  Displaced Workers: Provides data on workers wh...
# 27  Provides data on the number of children that w...
# 28  Provides data that will measure hunger and foo...
# 29  Provides information on population 3 years old...
# 30  Provides data for veterans of the United State...
# 31  Provides demographic information on persons wh...
# 32  The Congressional District Summary File (118th...
# 33  This product provides the population counts an...
# 34  This product will include topics such as age, ...
# 35  This product will include some of the demograp...
# 36  This product will include some of the demograp...
# 37  This product will include some of the demograp...
# 38  This product will include some of the demograp...
# 39  This product will include topics such as age, ...
# 40  The U.S. Census Bureau conducts the Island Are...
# 41  The U.S. Census Bureau conducts the Island Are...
# 42  The U.S. Census Bureau conducts the Island Are...
# 43  The U.S. Census Bureau conducts the Island Are...
# 44  Post-Enumeration Survey estimates of net cover...
# 45  Public Law 94-171, enacted in 1975, directs th...
# 46                Daily Decennial Self-Response Rates
# 47  Nonemployer Statistics is an annual series tha...
# 48  The PDB is a database of U.S. housing, demogra...
# 49  This is a one-time release of the Census Burea...
# 50  The PDB is a database of U.S. housing, demogra...
#
#                                          API BASE URL
# 0               http://api.census.gov/data/2020/abscb
# 1              http://api.census.gov/data/2020/abscbo
# 2               http://api.census.gov/data/2020/abscs
# 3              http://api.census.gov/data/2020/absmcb
# 4            http://api.census.gov/data/2020/acs/acs5
# 5   http://api.census.gov/data/2020/acs/acs5/cprofile
# 6    http://api.census.gov/data/2020/acs/acs5/profile
# 7       http://api.census.gov/data/2020/acs/acs5/pums
# 8     http://api.census.gov/data/2020/acs/acs5/pumspr
# 9    http://api.census.gov/data/2020/acs/acs5/subject
# 10          http://api.census.gov/data/2020/acs/flows
# 11                http://api.census.gov/data/2020/cbp
# 12       http://api.census.gov/data/2020/cps/arts/feb
# 13       http://api.census.gov/data/2020/cps/asec/mar
# 14      http://api.census.gov/data/2020/cps/basic/apr
# 15      http://api.census.gov/data/2020/cps/basic/aug
# 16      http://api.census.gov/data/2020/cps/basic/dec
# 17      http://api.census.gov/data/2020/cps/basic/feb
# 18      http://api.census.gov/data/2020/cps/basic/jan
# 19      http://api.census.gov/data/2020/cps/basic/jul
# 20      http://api.census.gov/data/2020/cps/basic/jun
# 21      http://api.census.gov/data/2020/cps/basic/mar
# 22      http://api.census.gov/data/2020/cps/basic/may
# 23      http://api.census.gov/data/2020/cps/basic/nov
# 24      http://api.census.gov/data/2020/cps/basic/oct
# 25      http://api.census.gov/data/2020/cps/basic/sep
# 26       http://api.census.gov/data/2020/cps/dwjt/jan
# 27  http://api.census.gov/data/2020/cps/fertility/jun
# 28    http://api.census.gov/data/2020/cps/foodsec/dec
# 29     http://api.census.gov/data/2020/cps/school/oct
# 30       http://api.census.gov/data/2020/cps/vets/aug
# 31     http://api.census.gov/data/2020/cps/voting/nov
# 32          http://api.census.gov/data/2020/dec/cd118
# 33          http://api.census.gov/data/2020/dec/ddhca
# 34            http://api.census.gov/data/2020/dec/dhc
# 35          http://api.census.gov/data/2020/dec/dhcas
# 36          http://api.census.gov/data/2020/dec/dhcgu
# 37          http://api.census.gov/data/2020/dec/dhcmp
# 38          http://api.census.gov/data/2020/dec/dhcvi
# 39             http://api.census.gov/data/2020/dec/dp
# 40           http://api.census.gov/data/2020/dec/dpas
# 41           http://api.census.gov/data/2020/dec/dpgu
# 42           http://api.census.gov/data/2020/dec/dpmp
# 43           http://api.census.gov/data/2020/dec/dpvi
# 44            http://api.census.gov/data/2020/dec/pes
# 45             http://api.census.gov/data/2020/dec/pl
# 46   http://api.census.gov/data/2020/dec/responserate
# 47             http://api.census.gov/data/2020/nonemp
# 48     http://api.census.gov/data/2020/pdb/blockgroup
# 49    http://api.census.gov/data/2020/pdb/statecounty
# 50          http://api.census.gov/data/2020/pdb/tract

# %% [markdown]
# ## Data sets available for all years

# %%
df_all_datasets = ced.variables.all_data_sets()

df_all_datasets
# Out:
#             YEAR                   DATASET  \
# 0           1986                       cbp
# 1           1987                       cbp
# 2           1988                       cbp
# 3           1989                       cbp
# 4           1989             cps/basic/apr
# ...          ...                       ...
# 1389  timeseries  timeseries/pseo/earnings
# 1390  timeseries     timeseries/pseo/flows
# 1391  timeseries         timeseries/qwi/rh
# 1392  timeseries         timeseries/qwi/sa
# 1393  timeseries         timeseries/qwi/se
#
#                                                   TITLE  \
# 0      1986 County Business Patterns: Business Patterns
# 1      1987 County Business Patterns: Business Patterns
# 2      1988 County Business Patterns: Business Patterns
# 3      1989 County Business Patterns: Business Patterns
# 4     Apr 1989 Current Population Survey: Basic Monthly
# ...                                                 ...
# 1389  Post-Secondary Employment Outcomes (PSEO): Pos...
# 1390  Post-Secondary Employment Outcomes (PSEO): Pos...
# 1391  Time Series Longitudinal Employer-Household Dy...
# 1392  Time Series Longitudinal Employer-Household Dy...
# 1393  Time Series Longitudinal Employer-Household Dy...
#
#                                             DESCRIPTION  \
# 0     County Business Patterns (CBP) is an annual se...
# 1     County Business Patterns (CBP) is an annual se...
# 2     County Business Patterns (CBP) is an annual se...
# 3     County Business Patterns (CBP) is an annual se...
# 4     To provide estimates of employment, unemployme...
# ...                                                 ...
# 1389  Post-Secondary Employment Outcomes (PSEO) are ...
# 1390  Post-Secondary Employment Outcomes (PSEO) are ...
# 1391  The Quarterly Workforce Indicators (QWI) are a...
# 1392  The Quarterly Workforce Indicators (QWI) are a...
# 1393  The Quarterly Workforce Indicators (QWI) are a...
#
#                                            API BASE URL
# 0                   http://api.census.gov/data/1986/cbp
# 1                   http://api.census.gov/data/1987/cbp
# 2                   http://api.census.gov/data/1988/cbp
# 3                   http://api.census.gov/data/1989/cbp
# 4         http://api.census.gov/data/1989/cps/basic/apr
# ...                                                 ...
# 1389  http://api.census.gov/data/timeseries/pseo/ear...
# 1390   http://api.census.gov/data/timeseries/pseo/flows
# 1391       http://api.census.gov/data/timeseries/qwi/rh
# 1392       http://api.census.gov/data/timeseries/qwi/sa
# 1393       http://api.census.gov/data/timeseries/qwi/se
#
# [1394 rows x 5 columns]

# %% [markdown]
# ## How many datasets by year.
#
# Some older years do not have very many vintage data sets. Note also that we have some `'timeseries'` datasets that are multi-year.
#
# We will plot which of the most popular datasets are available in which years, and how many other datasets there are.

# %%
datasets_to_count = {
    "ACS 1 Year": "acs/acs1",
    "ACS 3 Year": "acs/acs3",
    "ACS 5 Year": "acs/acs5",
    "Population Estimates": "pep/population",
    "Decennial Redistricting": "dec/pl",
}

s_counts_by_dataset = {
    name: df_all_datasets[df_all_datasets.DATASET == dataset]
    .groupby("YEAR")["DATASET"]
    .count()
    for name, dataset in datasets_to_count.items()
}


s_counts_other = {
    "Other": df_all_datasets[~df_all_datasets.DATASET.isin(datasets_to_count)]
    .groupby("YEAR")["DATASET"]
    .count()
}

# Make all the indices strings so when pandas sorts them it does not
# have a problem comparing ints and strings.
s_counts_other["Other"].index = s_counts_other["Other"].index.map(str)
for s_counts in s_counts_by_dataset.values():
    s_counts.index = s_counts.index.map(str)


df_years = pd.DataFrame([str(year) for year in range(1986, 2022)])

df_dataset_counts = df_years.join(
    pd.DataFrame(dict(s_counts_by_dataset, **s_counts_other)), how="outer"
)

df_dataset_counts
# Out:
#                0  ACS 1 Year  ACS 3 Year  ACS 5 Year  Population Estimates  \
# 0           1986         NaN         NaN         NaN                   NaN
# 1           1987         NaN         NaN         NaN                   NaN
# 2           1988         NaN         NaN         NaN                   NaN
# 3           1989         NaN         NaN         NaN                   NaN
# 4           1990         NaN         NaN         NaN                   NaN
# ...          ...         ...         ...         ...                   ...
# 2020         NaN         NaN         NaN         1.0                   NaN
# 2021         NaN         1.0         NaN         1.0                   1.0
# 2022         NaN         1.0         NaN         1.0                   NaN
# 2023         NaN         NaN         NaN         NaN                   NaN
# timeseries   NaN         NaN         NaN         NaN                   NaN
#
#             Decennial Redistricting  Other
# 0                               NaN    NaN
# 1                               NaN    NaN
# 2                               NaN    NaN
# 3                               NaN    NaN
# 4                               NaN    NaN
# ...                             ...    ...
# 2020                            1.0   51.0
# 2021                            NaN   55.0
# 2022                            NaN   37.0
# 2023                            NaN   13.0
# timeseries                      NaN   61.0
#
# [75 rows x 7 columns]

# %%
s_counts_other["Other"].index
# Out:
# Index(['1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        '2022', '2023', 'timeseries'],
#       dtype='object', name='YEAR')

# %%
s_counts_by_dataset["ACS 1 Year"].index
# Out:
# Index(['2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2021', '2022'],
#       dtype='object', name='YEAR')

# %%
ax = df_dataset_counts[datasets_to_count.keys()].plot.bar(stacked=True, figsize=(12, 8))

ax.set_title("Selected Popular Datasets by Vintage")

ax.set_yticks(range(5))

ax.grid(axis="y")

None

# %%
ax = df_dataset_counts.plot.bar(stacked=True, figsize=(12, 8))

ax.set_title("All Available Datasets by Vintage")

ax.grid(axis="y")

# %% [markdown]
# ## List the groups in a dataset

# %%
dataset = df_datasets_for_year.iloc[4]["DATASET"]
dataset
# Out:
# 'acs/acs5'

# %%
df_groups = ced.variables.all_groups(dataset, YEAR)

df_groups
# Out:
#        DATASET  YEAR    GROUP  \
# 0     acs/acs5  2020   B01001
# 1     acs/acs5  2020  B01001A
# 2     acs/acs5  2020  B01001B
# 3     acs/acs5  2020  B01001C
# 4     acs/acs5  2020  B01001D
# ...        ...   ...      ...
# 1135  acs/acs5  2020   C27014
# 1136  acs/acs5  2020   C27016
# 1137  acs/acs5  2020   C27017
# 1138  acs/acs5  2020   C27018
# 1139  acs/acs5  2020   C27021
#
#                                             DESCRIPTION
# 0                                            SEX BY AGE
# 1                              SEX BY AGE (WHITE ALONE)
# 2          SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)
# 3     SEX BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ...
# 4                              SEX BY AGE (ASIAN ALONE)
# ...                                                 ...
# 1135         PUBLIC HEALTH INSURANCE BY WORK EXPERIENCE
# 1136  HEALTH INSURANCE COVERAGE STATUS BY RATIO OF I...
# 1137  PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO...
# 1138  PUBLIC HEALTH INSURANCE BY RATIO OF INCOME TO ...
# 1139  HEALTH INSURANCE COVERAGE STATUS  BY LIVING AR...
#
# [1140 rows x 4 columns]

# %% [markdown]
# ## List the variables in a group

# %%
group = df_groups.iloc[-5]["GROUP"]
group
# Out:
# 'C27014'

# %%
df_variables = ced.variables.all_variables(dataset, YEAR, group)
df_variables
# Out:
#    YEAR   DATASET   GROUP     VARIABLE  \
# 0  2020  acs/acs5  C27014  C27014_001E
# 1  2020  acs/acs5  C27014  C27014_002E
# 2  2020  acs/acs5  C27014  C27014_003E
# 3  2020  acs/acs5  C27014  C27014_004E
# 4  2020  acs/acs5  C27014  C27014_005E
# 5  2020  acs/acs5  C27014  C27014_006E
# 6  2020  acs/acs5  C27014  C27014_007E
# 7  2020  acs/acs5  C27014  C27014_008E
# 8  2020  acs/acs5  C27014  C27014_009E
# 9  2020  acs/acs5  C27014  C27014_010E
#
#                                                LABEL  SUGGESTED_WEIGHT VALUES
# 0                                   Estimate!!Total:               NaN   None
# 1    Estimate!!Total:!!Worked full-time, year-round:               NaN   None
# 2  Estimate!!Total:!!Worked full-time, year-round...               NaN   None
# 3  Estimate!!Total:!!Worked full-time, year-round...               NaN   None
# 4  Estimate!!Total:!!Worked less than full-time, ...               NaN   None
# 5  Estimate!!Total:!!Worked less than full-time, ...               NaN   None
# 6  Estimate!!Total:!!Worked less than full-time, ...               NaN   None
# 7                    Estimate!!Total:!!Did not work:               NaN   None
# 8  Estimate!!Total:!!Did not work:!!With public c...               NaN   None
# 9  Estimate!!Total:!!Did not work:!!No public cov...               NaN   None

# %% [markdown]
# ## Show the variables in a tree

# %%
ced.variables.group_tree(dataset, YEAR, group)
# Out:
# + Estimate
#     + Total: (C27014_001E)
#         + Worked full-time, year-round: (C27014_002E)
#             + With public coverage (C27014_003E)
#             + No public coverage (C27014_004E)
#         + Worked less than full-time, year-round: (C27014_005E)
#             + With public coverage (C27014_006E)
#             + No public coverage (C27014_007E)
#         + Did not work: (C27014_008E)
#             + With public coverage (C27014_009E)
#             + No public coverage (C27014_010E)

# %% [markdown]
# ## List all the leaves of the tree

# %%
leaves = ced.variables.group_leaves(dataset, YEAR, group)
leaves
# Out:
# ['C27014_003E',
#  'C27014_004E',
#  'C27014_006E',
#  'C27014_007E',
#  'C27014_009E',
#  'C27014_010E']

# %% [markdown]
# ## Query the data

# %%
# Note that these two are equivalent. Using `leaves_of_group=group`
# could have saved us needing to construct `leaves` with the
# separate call above.

df_download_variables = ced.download(dataset, YEAR, leaves, state="*")
df_download_leaves_of_group = ced.download(
    dataset, YEAR, leaves_of_group=group, state="*"
)

df_download_leaves_of_group.equals(df_download_variables)
# Out:
# True

# %%
df_download_variables
# Out:
#    STATE  C27014_003E  C27014_004E  C27014_006E  C27014_007E  C27014_009E  \
# 0     42       282813      3936257       428403      1492576       691948
# 1     06      1374376     10959296      1773518      4694829      2306967
# 2     54        54298       456747        74180       163977       177283
# 3     49        32811       955292        48745       472159        75240
# 4     36       682381      5703442       901892      2135736      1276372
# 5     11        25265       257881        30201        78979        48885
# 6     02        23966       190562        32449       106897        34460
# 7     12       401669      6212125       399329      2513817       961401
# 8     45       107049      1493945       108716       580082       276030
# 9     38        14537       256412        16776       104423        19607
# 10    23        25533       407962        41683       178827        77363
# 11    13       168501      3314750       166185      1264296       462749
# 12    01        75843      1423256        78067       540687       320987
# 13    33        23957       461188        38029       182053        53264
# 14    41       119163      1175171       198499       532910       234140
# 15    56         8863       183814        10046        79873        17303
# 16    04       209241      1980455       251539       758185       396259
# 17    22       148697      1249862       173016       453971       363999
# 18    18       131642      2055323       198159       809014       337807
# 19    16        28632       499391        37380       245311        64417
# 20    09        92423      1081766       154354       443137       168766
# 21    15        33642       417542        43196       157676        58403
# 22    17       288510      3980277       409366      1511031       581603
# 23    25       235053      2122254       326100       878593       357411
# 24    48       429774      9129322       392899      3507585       964519
# 25    30        31841       295037        45156       140213        47166
# 26    31        29308       656923        31713       244400        50326
# 27    39       303814      3472694       462996      1321470       661439
# 28    08       161908      1816067       214518       726399       228801
# 29    34       173745      2838870       243804      1099656       366326
# 30    24       166291      1986115       190913       673236       257918
# 31    51       163082      2750475       159265      1045318       313113
# 32    50        21272       185998        32007        79282        34732
# 33    37       179393      3137513       214270      1263978       517007
# 34    05        91675       838456        99700       275666       237071
# 35    53       187247      2253788       291772       960869       361407
# 36    20        43783       944358        45237       369139        93556
# 37    40        65805      1175836        64873       457040       179996
# 38    55       115916      1907149       177397       727003       236847
# 39    28        46154       832804        53174       319814       206865
# 40    29        87163      1940917       110536       751474       278097
# 41    26       251826      2796716       413718      1228631       644554
# 42    44        30234       320975        43515       134701        64969
# 43    27       152178      1813873       222561       705573       196156
# 44    19        80034      1017463       108695       361520       125274
# 45    35        97998       497507       111490       181157       170661
# 46    32        77213       898084        94827       361572       153875
# 47    10        25494       285568        36096       102394        52158
# 48    72       121979       535502       208400       190812       609747
# 49    21       145764      1217060       191290       434073       387212
# 50    46        14846       287885        16505       109530        26141
# 51    47       160642      2031150       166729       760774       398301
#
#     C27014_010E
# 0        683856
# 1       2715925
# 2        112574
# 3        217961
# 4       1139733
# 5         30775
# 6         44862
# 7       1674842
# 8        370390
# 9         32869
# 10        58090
# 11       857110
# 12       406785
# 13        66680
# 14       233120
# 15        36047
# 16       479384
# 17       314243
# 18       386602
# 19       114182
# 20       197937
# 21        80596
# 22       816258
# 23       315603
# 24      2447273
# 25        53451
# 26        90420
# 27       609880
# 28       316622
# 29       593718
# 30       338402
# 31       577403
# 32        21750
# 33       770802
# 34       178118
# 35       456895
# 36       169884
# 37       314931
# 38       260607
# 39       243551
# 40       392648
# 41       562436
# 42        49605
# 43       219438
# 44       128039
# 45       131417
# 46       213596
# 47        54952
# 48       249120
# 49       231214
# 50        40652
# 51       475430
