# %% [markdown]
# # Variable Search
#
# Sometimes variable semantics change over time, especially in the ACS. `censusdis.variable.search` gives us a way
# to track these changes so we are sure we are using consistent data in multi-year studies. It also includes a regular
# expression search to help us find variables we are looking for. Finally, it can be narrowed to search only a specific
# group. This gives us flexibility to use it in many different ways as demonstrated below.

# %%
import censusdis.data as ced
from censusdis.datasets import ACS1

# %% [markdown]
# ## About `ced.variables.search`

# %%
help(ced.variables.search)
# Out:
# Help on method search in module censusdis.impl.varcache:
#
# search(dataset: str, vintage: Union[int, Iterable[int]], *, group_name: Optional[str] = None, name: Union[str, Iterable[str], NoneType] = None, pattern: Union[str, re.Pattern, NoneType] = None, case: bool = False) -> pandas.core.frame.DataFrame method of censusdis.impl.varcache.VariableCache instance
#     Retrieve information about the evolution of one of more variables in a data set over one or more vintages.
#
#     Parameters
#     ----------
#     dataset
#         The data set.
#     vintage
#         One or more Vintages to explore.
#     group_name
#         The group if we should explore only a single group. If `None` all groups
#         will be explored.
#     name
#         The name of one of more variables to explore. If `None` all variables are considered.
#         Normally at most one of `name` and `re` will be used.
#     pattern
#         A regular expression to match against the name and description of a variable. This
#         is used to filter down results. Normally at most one of `name` and `re` will be used.
#     case:
#         If `patters` is not `None` then indicates whether the regular expression match is
#         case sensitive. Does not affect the `name` match.
#
#     Returns
#     -------
#         A data frame of matching variables.

# %% [markdown]
# ## Look at the history of a variable over time
#
# `B08006_017E` is a variable that was repurposed after 2005. Also note that it did not
# exist in 2020.

# %%
VARIABLE = "B08006_017E"

# %%
df_variable_history = ced.variables.search(ACS1, range(2005, 2023), name=VARIABLE)

# %%
df_variable_history
# Out:
#     YEAR   DATASET   GROUP     VARIABLE                               LABEL  \
# 0   2005  acs/acs1  B08006  B08006_017E         Estimate!!Total!!Motorcycle
# 1   2006  acs/acs1  B08006  B08006_017E     Estimate!!Total!!Worked at home
# 2   2007  acs/acs1  B08006  B08006_017E     Estimate!!Total!!Worked at home
# 3   2008  acs/acs1  B08006  B08006_017E     Estimate!!Total!!Worked at home
# 4   2009  acs/acs1  B08006  B08006_017E     Estimate!!Total!!Worked at home
# 5   2010  acs/acs1  B08006  B08006_017E     Estimate!!Total!!Worked at home
# 6   2011  acs/acs1  B08006  B08006_017E     Estimate!!Total!!Worked at home
# 7   2012  acs/acs1  B08006  B08006_017E     Estimate!!Total!!Worked at home
# 8   2013  acs/acs1  B08006  B08006_017E     Estimate!!Total!!Worked at home
# 9   2014  acs/acs1  B08006  B08006_017E     Estimate!!Total!!Worked at home
# 10  2015  acs/acs1  B08006  B08006_017E     Estimate!!Total!!Worked at home
# 11  2016  acs/acs1  B08006  B08006_017E     Estimate!!Total!!Worked at home
# 12  2017  acs/acs1  B08006  B08006_017E     Estimate!!Total!!Worked at home
# 13  2018  acs/acs1  B08006  B08006_017E     Estimate!!Total!!Worked at home
# 14  2019  acs/acs1  B08006  B08006_017E  Estimate!!Total:!!Worked from home
# 15  2021  acs/acs1  B08006  B08006_017E  Estimate!!Total:!!Worked from home
# 16  2022  acs/acs1  B08006  B08006_017E  Estimate!!Total:!!Worked from home
#
#     SUGGESTED_WEIGHT VALUES
# 0                NaN   None
# 1                NaN   None
# 2                NaN   None
# 3                NaN   None
# 4                NaN   None
# 5                NaN   None
# 6                NaN   None
# 7                NaN   None
# 8                NaN   None
# 9                NaN   None
# 10               NaN   None
# 11               NaN   None
# 12               NaN   None
# 13               NaN   None
# 14               NaN   None
# 15               NaN   None
# 16               NaN   None

# %% [markdown]
# ## Search for variables about grandparents

# %%
df_grandparent_variables = ced.variables.search(ACS1, 2022, pattern="grandparent")

# %%
df_grandparent_variables
# Out:
#      YEAR   DATASET   GROUP     VARIABLE  \
# 0    2022  acs/acs1  B10002  B10002_002E
# 1    2022  acs/acs1  B10002  B10002_003E
# 2    2022  acs/acs1  B10002  B10002_004E
# 3    2022  acs/acs1  B10002  B10002_005E
# 4    2022  acs/acs1  B10010  B10010_002E
# ..    ...       ...     ...          ...
# 142  2022  acs/acs1  B10063  B10063_007E
# 143  2022  acs/acs1  B99104  B99104_003E
# 144  2022  acs/acs1  B99104  B99104_004E
# 145  2022  acs/acs1  B99104  B99104_005E
# 146  2022  acs/acs1  B99104  B99104_006E
#
#                                                  LABEL  SUGGESTED_WEIGHT  \
# 0    Estimate!!Total:!!Grandparent householder resp...               NaN
# 1    Estimate!!Total:!!Grandparent householder resp...               NaN
# 2    Estimate!!Total:!!Grandparent householder resp...               NaN
# 3    Estimate!!Total:!!Grandparent householder not ...               NaN
# 4    Estimate!!Median family income in the past 12 ...               NaN
# ..                                                 ...               ...
# 142  Estimate!!Total:!!Household without grandparen...               NaN
# 143  Estimate!!Total:!!Living with own grandchildre...               NaN
# 144  Estimate!!Total:!!Living with own grandchildre...               NaN
# 145  Estimate!!Total:!!Living with own grandchildre...               NaN
# 146  Estimate!!Total:!!Living with own grandchildre...               NaN
#
#     VALUES
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# ..     ...
# 142   None
# 143   None
# 144   None
# 145   None
# 146   None
#
# [147 rows x 7 columns]

# %% [markdown]
# What unique groups do they fall in?

# %%
df_grandparent_variables["GROUP"].unique()
# Out:
# array(['B10002', 'B10010', 'B10050', 'B10051A', 'B10051B', 'B10051C',
#        'B10051D', 'B10051E', 'B10051F', 'B10051G', 'B10051H', 'B10051I',
#        'B10051', 'B10052', 'B10053', 'B10054', 'B10056', 'B10057',
#        'B10058', 'B10059', 'B10063', 'B99104'], dtype=object)

# %% [markdown]
# We can also do the same search but within a single group.

# %%
ced.variables.search(ACS1, 2022, pattern="grandparent", group_name="B10054")
# Out:
#     YEAR   DATASET   GROUP     VARIABLE  \
# 0   2022  acs/acs1  B10054  B10054_003E
# 1   2022  acs/acs1  B10054  B10054_004E
# 2   2022  acs/acs1  B10054  B10054_005E
# 3   2022  acs/acs1  B10054  B10054_006E
# 4   2022  acs/acs1  B10054  B10054_009E
# 5   2022  acs/acs1  B10054  B10054_010E
# 6   2022  acs/acs1  B10054  B10054_011E
# 7   2022  acs/acs1  B10054  B10054_012E
# 8   2022  acs/acs1  B10054  B10054_014E
# 9   2022  acs/acs1  B10054  B10054_015E
# 10  2022  acs/acs1  B10054  B10054_016E
# 11  2022  acs/acs1  B10054  B10054_017E
#
#                                                 LABEL  SUGGESTED_WEIGHT VALUES
# 0   Estimate!!Total:!!Speak only English:!!Grandpa...               NaN   None
# 1   Estimate!!Total:!!Speak only English:!!Grandpa...               NaN   None
# 2   Estimate!!Total:!!Speak only English:!!Grandpa...               NaN   None
# 3   Estimate!!Total:!!Speak only English:!!Grandpa...               NaN   None
# 4   Estimate!!Total:!!Speak other language:!!Speak...               NaN   None
# 5   Estimate!!Total:!!Speak other language:!!Speak...               NaN   None
# 6   Estimate!!Total:!!Speak other language:!!Speak...               NaN   None
# 7   Estimate!!Total:!!Speak other language:!!Speak...               NaN   None
# 8   Estimate!!Total:!!Speak other language:!!Speak...               NaN   None
# 9   Estimate!!Total:!!Speak other language:!!Speak...               NaN   None
# 10  Estimate!!Total:!!Speak other language:!!Speak...               NaN   None
# 11  Estimate!!Total:!!Speak other language:!!Speak...               NaN   None

# %% [markdown]
# ## Has the number of variables in a group changed over time?

# %%
GROUP = "B08006"

# %%
df_group_vars = ced.variables.search(ACS1, range(2005, 2023), group_name=GROUP)

# %%
df_group_vars.groupby("YEAR")["VARIABLE"].count()
# Out:
# YEAR
# 2005    65
# 2006    53
# 2007    53
# 2008    53
# 2009    53
# 2010    53
# 2011    53
# 2012    53
# 2013    53
# 2014    53
# 2015    53
# 2016    53
# 2017    53
# 2018    53
# 2019    53
# 2021    53
# 2022    53
# Name: VARIABLE, dtype: int64

# %% [markdown]
# ## Sadly, the ACS has never asked any questions about tacos

# %%
df_taco = ced.variables.search(ACS1, range(2005, 2023), pattern="taco")
df_taco
# Out:
# Empty DataFrame
# Columns: [YEAR, DATASET, GROUP, VARIABLE, LABEL, SUGGESTED_WEIGHT, VALUES]
# Index: []
